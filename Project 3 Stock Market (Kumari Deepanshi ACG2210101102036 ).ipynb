# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15 , 6

# %% [markdown]
# Check the Current Working Directory

# %%
display(os.getcwd())
# Out:
# 'C:\\Users\\Deepanshi'

# %% [markdown]
# Change the Current Working Directory

# %%
os.chdir('C:\\Deepanshi\\Machine Learning\\Project 3 Stock Market\\')
display (os.getcwd())
# Out:
# 'C:\\Deepanshi\\Machine Learning\\Project 3 Stock Market'

# %% [markdown]
# Read and Display the Data Set

# %%
#calling the file in nyse named prices.csv
df = pd.read_csv("prices.csv" , header = 0)
display(df)
# Out:
#                        date symbol        open       close         low  \
# 0       2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1       2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2       2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3       2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4       2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                     ...    ...         ...         ...         ...
# 851259           2016-12-30    ZBH  103.309998  103.199997  102.849998
# 851260           2016-12-30   ZION   43.070000   43.040001   42.689999
# 851261           2016-12-30    ZTS   53.639999   53.529999   53.270000
# 851262  2016-12-30 00:00:00    AIV   44.730000   45.450001   44.410000
# 851263  2016-12-30 00:00:00    FTV   54.200001   53.630001   53.389999
#
#               high     volume
# 0       126.250000  2163600.0
# 1       125.540001  2386400.0
# 2       119.739998  2489500.0
# 3       117.440002  2006300.0
# 4       117.330002  1408600.0
# ...            ...        ...
# 851259  103.930000   973800.0
# 851260   43.310001  1938100.0
# 851261   53.740002  1701200.0
# 851262   45.590000  1380900.0
# 851263   54.480000   705100.0
#
# [851264 rows x 7 columns]

# %% [markdown]
# # Data Descriptions

# %% [markdown]
# Display the Shape

# %%
print(df.shape)
# Out:
# (851264, 7)

# %% [markdown]
# Display the Column names

# %%
print(df.columns)
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
#Value Count (Number of Record by company)
df.symbol.value_counts()
# Out:
# KSU     1762
# NOC     1762
# ORCL    1762
# OMC     1762
# OKE     1762
#         ...
# KHC      378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: symbol, Length: 501, dtype: int64

# %%
#Unique Values
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
#        'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DLR',
#        'DLTR', 'DNB', 'DOV', 'DOW', 'DPS', 'DRI', 'DTE', 'DUK', 'DVA',
#        'DVN', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR',
#        'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESRX', 'ESS', 'ETFC',
#        'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST',
#        'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR',
#        'FLR', 'FLS', 'FMC', 'FOX', 'FOXA', 'FRT', 'FSLR', 'FTI', 'FTR',
#        'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GOOG', 'GOOGL', 'GPC',
#        'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAR', 'HAS',
#        'HBAN', 'HBI', 'HCN', 'HCP', 'HD', 'HES', 'HIG', 'HOG', 'HOLX',
#        'HON', 'HP', 'HPQ', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY',
#        'HUM', 'IBM', 'ICE', 'IDXX', 'IFF', 'ILMN', 'INTC', 'INTU', 'IP',
#        'IPG', 'IR', 'IRM', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JEC',
#        'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KEY', 'KIM', 'KLAC', 'KMB',
#        'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L', 'LB', 'LEG', 'LEN', 'LH',
#        'LKQ', 'LLL', 'LLTC', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX',
#        'LUK', 'LUV', 'LVLT', 'M', 'MA', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT',
#        'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MHK', 'MJN',
#        'MKC', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MON', 'MOS', 'MRK',
#        'MRO', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MUR', 'MYL', 'NBL',
#        'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE', 'NOC', 'NOV',
#        'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'O', 'OKE',
#        'OMC', 'ORCL', 'ORLY', 'OXY', 'PAYX', 'PBCT', 'PBI', 'PCAR', 'PCG',
#        'PCLN', 'PDCO', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH',
#        'PHM', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL',
#        'PRGO', 'PRU', 'PSA', 'PVH', 'PWR', 'PX', 'PXD', 'QCOM', 'R',
#        'RAI', 'RCL', 'REGN', 'RF', 'RHI', 'RHT', 'RIG', 'RL', 'ROK',
#        'ROP', 'ROST', 'RRC', 'RSG', 'RTN', 'SBUX', 'SCG', 'SCHW', 'SE',
#        'SEE', 'SHW', 'SIG', 'SJM', 'SLB', 'SLG', 'SNA', 'SNI', 'SO',
#        'SPG', 'SPGI', 'SPLS', 'SRCL', 'SRE', 'STI', 'STT', 'STX', 'STZ',
#        'SWK', 'SWKS', 'SWN', 'SYK', 'SYMC', 'SYY', 'T', 'TAP', 'TDC',
#        'TEL', 'TGNA', 'TGT', 'TIF', 'TJX', 'TMK', 'TMO', 'TROW', 'TRV',
#        'TSCO', 'TSN', 'TSO', 'TSS', 'TWX', 'TXN', 'TXT', 'UAA', 'UAL',
#        'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URBN', 'URI',
#        'USB', 'UTX', 'V', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC', 'VNO',
#        'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAT', 'WBA', 'WDC', 'WEC',
#        'WFC', 'WFM', 'WHR', 'WM', 'WMB', 'WMT', 'WU', 'WY', 'WYN', 'WYNN',
#        'XEC', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YHOO', 'YUM',
#        'ZBH', 'ZION', 'AIV', 'CHTR', 'LYB', 'GM', 'ABBV', 'DLPH', 'FB',
#        'FBHS', 'HCA', 'KMI', 'KORS', 'MPC', 'NLSN', 'PSX', 'TDG', 'TRIP',
#        'XYL', 'ZTS', 'COTY', 'MNK', 'NWS', 'NWSA', 'EVHC', 'ALLE', 'CFG',
#        'NAVI', 'QRVO', 'SYF', 'WRK', 'KHC', 'PYPL', 'HPE', 'CSRA', 'FTV'],
#       dtype=object)

# %%
#Number  of Unique Values
display(df.symbol.unique().shape)
# Out:
# (501,)

# %%
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %%
#Number of Record
print(len(df.symbol.values))
# Out:
# 851264

# %%
#Display Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
#Describe the Column
df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       70.836986      70.857109      70.118414      71.543476
# std        83.695876      83.689686      82.877294      84.465504
# min         0.850000       0.860000       0.830000       0.880000
# 25%        33.840000      33.849998      33.480000      34.189999
# 50%        52.770000      52.799999      52.230000      53.310001
# 75%        79.879997      79.889999      79.110001      80.610001
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
# Check the NUll values
df.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
#Get All Unique Values
df.date.unique()
# Out:
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2016-12-28', '2016-12-29',
#        '2016-12-30'], dtype=object)

# %%
#Display Date as Data Frame
pd.DataFrame(df.date.unique())
# Out:
#                         0
# 0     2016-01-05 00:00:00
# 1     2016-01-06 00:00:00
# 2     2016-01-07 00:00:00
# 3     2016-01-08 00:00:00
# 4     2016-01-11 00:00:00
# ...                   ...
# 3519           2016-12-23
# 3520           2016-12-27
# 3521           2016-12-28
# 3522           2016-12-29
# 3523           2016-12-30
#
# [3524 rows x 1 columns]

# %%
# Check the Duplicate Records
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Load the Files

# %%
comp_info = pd.read_csv('securities.csv')
comp_info
# Out:
#     Ticker symbol                Security SEC filings             GICS Sector  \
# 0             MMM              3M Company     reports             Industrials
# 1             ABT     Abbott Laboratories     reports             Health Care
# 2            ABBV                  AbbVie     reports             Health Care
# 3             ACN           Accenture plc     reports  Information Technology
# 4            ATVI     Activision Blizzard     reports  Information Technology
# ..            ...                     ...         ...                     ...
# 500          YHOO              Yahoo Inc.     reports  Information Technology
# 501           YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503          ZION           Zions Bancorp     reports              Financials
# 504           ZTS                  Zoetis     reports             Health Care
#
#                   GICS Sub Industry   Address of Headquarters  \
# 0          Industrial Conglomerates       St. Paul, Minnesota
# 1             Health Care Equipment   North Chicago, Illinois
# 2                   Pharmaceuticals   North Chicago, Illinois
# 3    IT Consulting & Other Services           Dublin, Ireland
# 4       Home Entertainment Software  Santa Monica, California
# ..                              ...                       ...
# 500    Internet Software & Services     Sunnyvale, California
# 501                     Restaurants      Louisville, Kentucky
# 502           Health Care Equipment           Warsaw, Indiana
# 503                  Regional Banks      Salt Lake City, Utah
# 504                 Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK
# 0                NaN    66740
# 1         31-03-1964     1800
# 2         31-12-2012  1551152
# 3         06-07-2011  1467373
# 4         31-08-2015   718877
# ..               ...      ...
# 500              NaN  1011006
# 501       06-10-1997  1041061
# 502              NaN  1136869
# 503              NaN   109380
# 504       21-06-2013  1555280
#
# [505 rows x 8 columns]

# %% [markdown]
# Data Description

# %%
comp_info["Ticker symbol"].nunique()
comp_info.info()
comp_info.isnull().sum()
comp_info.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ticker symbol            505 non-null    object
#  1   Security                 505 non-null    object
#  2   SEC filings              505 non-null    object
#  3   GICS Sector              505 non-null    object
#  4   GICS Sub Industry        505 non-null    object
#  5   Address of Headquarters  505 non-null    object
#  6   Date first added         307 non-null    object
#  7   CIK                      505 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.7+ KB
#                 CIK
# count  5.050000e+02
# mean   7.074490e+05
# std    5.144375e+05
# min    1.800000e+03
# 25%    8.631200e+04
# 50%    8.310010e+05
# 75%    1.075531e+06
# max    1.659166e+06

# %% [markdown]
# Search For Particular company Details

# %%
comp_info.loc[comp_info.Security.str.startswith('Face'),:]
# Out:
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK
# 181  1326801

# %%
comp_info.loc[comp_info.Security.str.startswith('Acc'),:]
# Out:
#   Ticker symbol       Security SEC filings             GICS Sector  \
# 3           ACN  Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 3  IT Consulting & Other Services         Dublin, Ireland       06-07-2011
#
#        CIK
# 3  1467373

# %%
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc') 
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"] 
print(comp_plot)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object

# %%
#For LOOP to display 6 Company Names
for i in comp_plot:
    print (i)
# Out:
# ADBE
# FB
# GS
# MSFT
# XRX
# YHOO

# %% [markdown]
# Create a function to plot Graphs for selected companies  opening stock and closing stock against time

# %%
def plotter(code):
    
    global closing_stock ,opening_stock
    
    f, axs = plt.subplots(2,2,figsize=(15,8))
    
    plt.subplot(212)
   
    company = df[df['symbol']==code]
    
    company = company.open.values.astype('float32')

    company = company.reshape(-1, 1)
    
    opening_stock = company
    
    
    plt.grid(True)
    plt.xlabel('Time') 
    
    plt.ylabel(code + " open stock prices") 
    plt.title('prices Vs Time') 
    plt.plot(company , 'g') 
   
    plt.subplot(211)
    
    company_close = df[df['symbol']==code]
    
    company_close = company_close.close.values.astype('float32')
    
    company_close = company_close.reshape(-1, 1)
    
    closing_stock = company_close
    
    # plotting the data graph between "Time" and "prices vs time"
    plt.xlabel('Time') 
    plt.ylabel(code + " close stock prices")
    plt.title('prices Vs Time') 
    plt.grid(True) 
    plt.plot(company_close , 'b') 
    plt.show()

# %%
for i in comp_plot:
    plotter(i)

# %% [markdown]
# # Plot Summary

# %% [markdown]
# Extract closing stock   of one company, here YHOO

# %%
stocks= np.array (df[df.symbol.isin (['YHOO'])].close)
print(stocks)
# Out:
# [17.1      17.23     17.17     ... 38.73     38.639999 38.669998]

# %% [markdown]
# Display Shape

# %%
display (stocks.shape)
# Out:
# (1762,)

# %% [markdown]
# Convert stock to 2D array

# %%
stocks = stocks.reshape(len(stocks) , 1)
print (stocks.shape)
print(stocks)
# Out:
# (1762, 1)
# [[17.1     ]
#  [17.23    ]
#  [17.17    ]
#  ...
#  [38.73    ]
#  [38.639999]
#  [38.669998]]

# %% [markdown]
# # Min Max Scaler

# %% [markdown]
# Feature scaling the vector for better model performance.

# %%
from sklearn.preprocessing import MinMaxScaler
#scaling features between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1)) 
stocks = scaler.fit_transform(stocks) 
display (stocks)
# Out:
# array([[0.14559109],
#        [0.14874031],
#        [0.14728683],
#        ...,
#        [0.66957366],
#        [0.6673934 ],
#        [0.66812012]])

# %% [markdown]
# Train Test Split (80 % Training and 20 % Test Data)

# %%
#Total Number of Records
print (stocks.shape) 

# 80 % Training record count   
train = int(len(stocks) * 0.80)
print (train)

# 20 % record count    (Total – 80%)
test = len(stocks) - train 
print (test)
# Out:
# (1762, 1)
# 1409
# 353

# %% [markdown]
# Training data

# %%
#divinding the values of stocks data to train from 0 to 1409 i.e 80% data
train = stocks[0:train]
display (train.shape)
print(train)
# Out:
# (1409, 1)
# [[0.14559109]
#  [0.14874031]
#  [0.14728683]
#  ...
#  [0.63372095]
#  [0.61458332]
#  [0.61967051]]

# %% [markdown]
# Test Data

# %%
#divinding the values of stocks data to test from train ending to stock data ending i.e rest 20% data
test = stocks[len(train) : ]
display(test.shape)
display (test)
# Out:
# (353, 1)
# array([[0.63129851],
#        [0.60416666],
#        [0.56686053],
#        [0.6017442 ],
#        [0.60925394],
#        [0.60586237],
#        [0.59593022],
#        [0.58381782],
#        [0.55741276],
#        [0.52906978],
#        [0.48982557],
#        [0.50024226],
#        [0.51913761],
#        [0.54748061],
#        [0.53415697],
#        [0.51235471],
#        [0.49685079],
#        [0.500969  ],
#        [0.51962213],
#        [0.49636629],
#        [0.47989342],
#        [0.4949128 ],
#        [0.48594962],
#        [0.49273257],
#        [0.46584303],
#        [0.48328492],
#        [0.49200583],
#        [0.48062017],
#        [0.47601745],
#        [0.48643412],
#        [0.46778102],
#        [0.45179265],
#        [0.44210272],
#        [0.43701549],
#        [0.39995156],
#        [0.41593993],
#        [0.43168606],
#        [0.43168606],
#        [0.47529068],
#        [0.47868218],
#        [0.48134689],
#        [0.50339151],
#        [0.51550386],
#        [0.51913761],
#        [0.52737407],
#        [0.51477714],
#        [0.50872094],
#        [0.54239342],
#        [0.53972867],
#        [0.54287792],
#        [0.52664735],
#        [0.4852229 ],
#        [0.49854652],
#        [0.53488369],
#        [0.54045549],
#        [0.56225774],
#        [0.58381782],
#        [0.58042635],
#        [0.59423449],
#        [0.58575583],
#        [0.57243221],
#        [0.58091087],
#        [0.58212208],
#        [0.55983531],
#        [0.54723839],
#        [0.55474812],
#        [0.53997097],
#        [0.53633722],
#        [0.5111434 ],
#        [0.5295543 ],
#        [0.52737407],
#        [0.53028102],
#        [0.52180236],
#        [0.53343027],
#        [0.53948647],
#        [0.5297965 ],
#        [0.53464149],
#        [0.529312  ],
#        [0.55038763],
#        [0.54796511],
#        [0.5949613 ],
#        [0.56322676],
#        [0.5770349 ],
#        [0.57146319],
#        [0.57558136],
#        [0.56468029],
#        [0.57025198],
#        [0.52858528],
#        [0.52083335],
#        [0.53149224],
#        [0.54966084],
#        [0.53633722],
#        [0.5295543 ],
#        [0.5300388 ],
#        [0.55959301],
#        [0.56589151],
#        [0.55765508],
#        [0.54530035],
#        [0.55595934],
#        [0.53972867],
#        [0.53706392],
#        [0.49200583],
#        [0.5113857 ],
#        [0.51041668],
#        [0.46196707],
#        [0.4733527 ],
#        [0.46220931],
#        [0.47480624],
#        [0.44452523],
#        [0.46584303],
#        [0.43725774],
#        [0.45179265],
#        [0.42853686],
#        [0.44137596],
#        [0.45203489],
#        [0.45276166],
#        [0.4576066 ],
#        [0.45058143],
#        [0.42781009],
#        [0.44622094],
#        [0.44767443],
#        [0.43531975],
#        [0.40188954],
#        [0.43750001],
#        [0.40891471],
#        [0.38662789],
#        [0.38105621],
#        [0.38783916],
#        [0.37960272],
#        [0.38638569],
#        [0.44064926],
#        [0.44282949],
#        [0.44404071],
#        [0.45906011],
#        [0.48643412],
#        [0.47432172],
#        [0.48110469],
#        [0.49103686],
#        [0.49127911],
#        [0.50145352],
#        [0.52592053],
#        [0.52858528],
#        [0.52785856],
#        [0.55159887],
#        [0.55402131],
#        [0.52906978],
#        [0.54312012],
#        [0.52640505],
#        [0.55038763],
#        [0.54481595],
#        [0.53706392],
#        [0.55523252],
#        [0.56177325],
#        [0.5833333 ],
#        [0.59060081],
#        [0.5891473 ],
#        [0.57437014],
#        [0.57582368],
#        [0.58478684],
#        [0.61119188],
#        [0.61700585],
#        [0.62306205],
#        [0.61506784],
#        [0.62814924],
#        [0.61337211],
#        [0.61942831],
#        [0.60755811],
#        [0.60513567],
#        [0.61506784],
#        [0.61942831],
#        [0.63517446],
#        [0.63178291],
#        [0.61579454],
#        [0.61603684],
#        [0.61143417],
#        [0.64801358],
#        [0.64389532],
#        [0.63929265],
#        [0.63323645],
#        [0.6303295 ],
#        [0.62645353],
#        [0.61773257],
#        [0.61797477],
#        [0.61627906],
#        [0.60368214],
#        [0.60343994],
#        [0.62621123],
#        [0.63323645],
#        [0.63202521],
#        [0.63832363],
#        [0.6366279 ],
#        [0.62839146],
#        [0.61506784],
#        [0.63929265],
#        [0.63420544],
#        [0.63347875],
#        [0.62814924],
#        [0.61555234],
#        [0.61942831],
#        [0.64050387],
#        [0.59350777],
#        [0.62185074],
#        [0.64752909],
#        [0.65043604],
#        [0.61918611],
#        [0.63129851],
#        [0.61797477],
#        [0.62936048],
#        [0.62112405],
#        [0.62693802],
#        [0.63614338],
#        [0.62354658],
#        [0.61482562],
#        [0.63735472],
#        [0.63541668],
#        [0.63711239],
#        [0.62621123],
#        [0.63468996],
#        [0.63735472],
#        [0.6363857 ],
#        [0.64656007],
#        [0.60925394],
#        [0.58454461],
#        [0.60440895],
#        [0.6242733 ],
#        [0.64123066],
#        [0.65164735],
#        [0.63977715],
#        [0.64001935],
#        [0.64026164],
#        [0.64559115],
#        [0.65092053],
#        [0.6492248 ],
#        [0.6431686 ],
#        [0.65092053],
#        [0.64510663],
#        [0.65067833],
#        [0.65600772],
#        [0.67369193],
#        [0.67248059],
#        [0.68531981],
#        [0.65964149],
#        [0.67030036],
#        [0.66787792],
#        [0.66448645],
#        [0.65649224],
#        [0.67126937],
#        [0.66569769],
#        [0.6613372 ],
#        [0.67417632],
#        [0.67587216],
#        [0.68192836],
#        [0.68192836],
#        [0.69864343],
#        [0.73110467],
#        [0.77156007],
#        [0.76501935],
#        [0.76065898],
#        [0.76574617],
#        [0.77059115],
#        [0.77349808],
#        [0.76138568],
#        [0.76332361],
#        [0.74660855],
#        [0.7495155 ],
#        [0.75532948],
#        [0.75508718],
#        [0.76283921],
#        [0.76695738],
#        [0.77131785],
#        [0.77979651],
#        [0.81443798],
#        [0.80571703],
#        [0.80595935],
#        [0.77107555],
#        [0.78415697],
#        [0.7739826 ],
#        [0.78415697],
#        [0.79699619],
#        [0.78924416],
#        [0.77761627],
#        [0.7679264 ],
#        [0.80062984],
#        [0.80087216],
#        [0.7681686 ],
#        [0.755814  ],
#        [0.78197674],
#        [0.78972868],
#        [0.76259692],
#        [0.77543602],
#        [0.77616283],
#        [0.77737405],
#        [0.79021317],
#        [0.78948645],
#        [0.77834307],
#        [0.79530036],
#        [0.76526165],
#        [0.75750973],
#        [0.73958333],
#        [0.73522286],
#        [0.74370159],
#        [0.74103684],
#        [0.76647289],
#        [0.75799423],
#        [0.75290695],
#        [0.76308141],
#        [0.7621124 ],
#        [0.75072681],
#        [0.74563953],
#        [0.7434593 ],
#        [0.73788759],
#        [0.73255821],
#        [0.71681203],
#        [0.70591087],
#        [0.70712209],
#        [0.72577519],
#        [0.72843994],
#        [0.72965116],
#        [0.70421513],
#        [0.71051353],
#        [0.68338178],
#        [0.70542635],
#        [0.72407947],
#        [0.73546516],
#        [0.72916666],
#        [0.72722872],
#        [0.72480617],
#        [0.72359495],
#        [0.72141472],
#        [0.73546516],
#        [0.73909881],
#        [0.72504847],
#        [0.69137601],
#        [0.7020349 ],
#        [0.70518415],
#        [0.69961244],
#        [0.71293606],
#        [0.73449614],
#        [0.74297478],
#        [0.73183139],
#        [0.73594965],
#        [0.72238374],
#        [0.66182172],
#        [0.66666671],
#        [0.66206392],
#        [0.67999033],
#        [0.67974813],
#        [0.66400195],
#        [0.66787792],
#        [0.67417632],
#        [0.66957366],
#        [0.6673934 ],
#        [0.66812012]])

# %% [markdown]
# Function to prepare the data, use two previous values to predict for third data

# %%
#creating function to create trainX,testX and target(trainY, testY)
def process_data(data , n_features):
    dataX, dataY = [], [] # creating data for dataset and dividing inta X,Y
    for i in range(len(data)-n_features):
        # taking i range from total size- 3 
        a = data[i:(i+n_features), 0]
        # Here a is value of data from i to i+ n_features, ie two values and put it in dataX 
        dataX.append(a) #putting a in dataX
        #here dataY takes the value of data of i + n_features
        dataY.append(data[i + n_features, 0])
        # putting i+ n_features in  dataY
    return np.array(dataX), np.array(dataY)
# returning dataX and dataY in array

# %% [markdown]
# Call the function to prepare training data

# %%
n_features = 2
# Here we create train X, Train Y and test X, Test Y data where trainX, testX has two value is each block

trainX, trainY = process_data(train, n_features)
print(trainX.shape , trainY.shape)

#Call the function to prepare test data - n_features = 2

testX, testY = process_data(test, n_features)
print (testX.shape , testY.shape)

#Call the function to prepare full  data - n_features = 2
stocksX, stocksY = process_data(stocks, n_features)
print (stocksX.shape , stocksY.shape)

#Display the First 10 Records from Train X 
display (trainX[:10])

#Display the First 10 Records from TrainY
display (trainY[:10])
# Out:
# (1407, 2) (1407,)
# (351, 2) (351,)
# (1760, 2) (1760,)
# array([[0.14559109, 0.14874031],
#        [0.14874031, 0.14728683],
#        [0.14728683, 0.13590119],
#        [0.13590119, 0.13590119],
#        [0.13590119, 0.13687016],
#        [0.13687016, 0.13541667],
#        [0.13541667, 0.14074613],
#        [0.14074613, 0.14607561],
#        [0.14607561, 0.13880814],
#        [0.13880814, 0.13711241]])
# array([0.14728683, 0.13590119, 0.13590119, 0.13687016, 0.13541667,
#        0.14074613, 0.14607561, 0.13880814, 0.13711241, 0.1281492 ])

# %% [markdown]
# Reshape to 3D array to use for LSTM /Deep Learning model

# %% [markdown]
# #

# %% [markdown]
# # Import Libraries

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\deepanshi\anaconda3\lib\site-packages (2.9.0)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# Requirement already satisfied: tensorflow in c:\users\deepanshi\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: setuptools in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: packaging in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.6.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\deepanshi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\deepanshi\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\deepanshi\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: setuptools in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\deepanshi\anaconda3\lib\site-packages)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: packaging in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\deepanshi\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.6.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\deepanshi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\deepanshi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\deepanshi\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)

# %%
import math 
from keras.models import Sequential 
from keras.layers import Dense , BatchNormalization , Dropout , Activation 
from keras.layers import LSTM , GRU 
from sklearn.preprocessing import MinMaxScaler 
from sklearn.metrics import mean_squared_error 
from keras.optimizers import Adam , SGD , RMSprop

# %%
filepath="stock_weights1.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, min_delta=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# #

# %% [markdown]
# # Create the model – Fully connected Layer

# %%
model = Sequential()
model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(256))
model.add(Dropout(0.4))
model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(1))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 256)            199680
#
#  dropout (Dropout)           (None, 1, 256)            0
#
#  lstm (LSTM)                 (None, 256)               525312
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 741,505
# Trainable params: 741,505
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
#  Compile the Model

# %%
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])

# %% [markdown]
# Fit the Model

# %%
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 , 
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))
# Out:
# Epoch 1/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.1517 - mean_squared_error: 0.1517
# Epoch 1: val_loss improved from -inf to 0.16196, saving model to stock_weights1.hdf5
# 11/11 [==============================] - 10s 256ms/step - loss: 0.1418 - mean_squared_error: 0.1418 - val_loss: 0.1620 - val_mean_squared_error: 0.1620 - lr: 5.0000e-04
# Epoch 2/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0364 - mean_squared_error: 0.0364
# Epoch 2: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - lr: 5.0000e-04
# Epoch 3/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0200 - mean_squared_error: 0.0200
# Epoch 3: val_loss did not improve from 0.16196
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 5.0000e-04
# Epoch 4/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 4: val_loss did not improve from 0.16196
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - lr: 5.0000e-05
# Epoch 5/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 5: val_loss did not improve from 0.16196
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-06
# Epoch 6/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 6: val_loss did not improve from 0.16196
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-07
# Epoch 7/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 7: val_loss did not improve from 0.16196
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-08
# Epoch 8/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 8: val_loss did not improve from 0.16196
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-09
# Epoch 9/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 9: val_loss did not improve from 0.16196
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-10
# Epoch 10/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 10: val_loss did not improve from 0.16196
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-11
# Epoch 11/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 11: val_loss did not improve from 0.16196
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-12
# Epoch 12/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 12: val_loss did not improve from 0.16196
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-13
# Epoch 13/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 13: val_loss did not improve from 0.16196
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-14
# Epoch 14/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 14: val_loss did not improve from 0.16196
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-15
# Epoch 15/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 15: val_loss did not improve from 0.16196
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-16
# Epoch 16/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 16: val_loss did not improve from 0.16196
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-17
# Epoch 17/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 17: val_loss did not improve from 0.16196
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-18
# Epoch 18/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 18: val_loss did not improve from 0.16196
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-19
# Epoch 19/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 19: val_loss did not improve from 0.16196
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-20
# Epoch 20/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 20: val_loss did not improve from 0.16196
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-21
# Epoch 21/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 21: val_loss did not improve from 0.16196
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-22
# Epoch 22/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 22: val_loss did not improve from 0.16196
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-23
# Epoch 23/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 23: val_loss did not improve from 0.16196
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-24
# Epoch 24/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 24: val_loss did not improve from 0.16196
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-25
# Epoch 25/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 25: val_loss did not improve from 0.16196
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-26
# Epoch 26/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 26: val_loss did not improve from 0.16196
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-27
# Epoch 27/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 27: val_loss did not improve from 0.16196
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-28
# Epoch 28/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 28: val_loss did not improve from 0.16196
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-29
# Epoch 29/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 29: val_loss did not improve from 0.16196
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-30
# Epoch 30/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 30: val_loss did not improve from 0.16196
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-31
# Epoch 31/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 31: val_loss did not improve from 0.16196
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-32
# Epoch 32/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 32: val_loss did not improve from 0.16196
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-33
# Epoch 33/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 33: val_loss did not improve from 0.16196
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-34
# Epoch 34/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 34: val_loss did not improve from 0.16196
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-35
# Epoch 35/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 35: val_loss did not improve from 0.16196
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-36
# Epoch 36/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 36: val_loss did not improve from 0.16196
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-37
# Epoch 37/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 37: val_loss did not improve from 0.16196
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-38
# Epoch 38/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 38: val_loss did not improve from 0.16196
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-39
# Epoch 39/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 39: val_loss did not improve from 0.16196
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-40
# Epoch 40/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 40: val_loss did not improve from 0.16196
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0000e-41
# Epoch 41/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 41: val_loss did not improve from 0.16196
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 4.9998e-42
# Epoch 42/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 42: val_loss did not improve from 0.16196
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0026e-43
# Epoch 43/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 43: val_loss did not improve from 0.16196
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.0447e-44
# Epoch 44/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 44: val_loss did not improve from 0.16196
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 5.6052e-45
# Epoch 45/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 45: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 46/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 46: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 47/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 47: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 48/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 48: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 49/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 49: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 50/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 50: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 51/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 51: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 52/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 52: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 44ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 53/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 53: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 54/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 54: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 55/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 55: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 56/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 56: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 57/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 57: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 58/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 58: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 59/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 59: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 60/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 60: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 61/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 61: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 62/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 62: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 63/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 63: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 64/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 64: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 65/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 65: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 66/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 66: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 67/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 67: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 68/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 68: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 69/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 69: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 70/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 70: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 71/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 71: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 72/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 72: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 73/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 73: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 74/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 74: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 75/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 75: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 76/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 76: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 77/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 77: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 78/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 78: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 79/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 79: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 80/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 80: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 81/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 81: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 82/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 82: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 83/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 83: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 84/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 84: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 85/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 85: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 86/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 86: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 87/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 87: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 88/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 88: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 89/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 89: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 90/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 90: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 91/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 91: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 47ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 92/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 92: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 93/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 93: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 94/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 94: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 95/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 95: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 96/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 96: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 97/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 97: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 98/100
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 98: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 99/100
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 99: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00
# Epoch 100/100
# 11/11 [==============================] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 100: val_loss did not improve from 0.16196
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 0.0000e+00

# %%
test_pred = model.predict(testX)
display (test_pred [:10])
# Out:
# 11/11 [==============================] - 2s 5ms/step
# array([[0.5758731 ],
#        [0.5525064 ],
#        [0.5501701 ],
#        [0.56621426],
#        [0.5679412 ],
#        [0.56319785],
#        [0.5551844 ],
#        [0.5414196 ],
#        [0.52154315],
#        [0.49727088]], dtype=float32)

# %%
test_pred = scaler.inverse_transform(test_pred)
display (test_pred [:10])
# Out:
# array([[34.862038],
#        [33.89746 ],
#        [33.80102 ],
#        [34.463326],
#        [34.53461 ],
#        [34.338806],
#        [34.00801 ],
#        [33.4398  ],
#        [32.6193  ],
#        [31.61734 ]], dtype=float32)

# %%
testY = testY.reshape(testY.shape[0] , 1)
testY = scaler.inverse_transform(testY)
display (testY[:10])
# Out:
# array([[34.490002],
#        [35.93    ],
#        [36.240002],
#        [36.099998],
#        [35.689999],
#        [35.189999],
#        [34.099998],
#        [32.93    ],
#        [31.309999],
#        [31.74    ]])

# %%
from sklearn.metrics import r2_score
r2_score(testY,test_pred)
# Out:
# 0.7641842538973525

# %% [markdown]
# # Plot the Graph Actual and Predicted Data

# %%
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)

plt.plot(testY , 'b')

plt.plot(test_pred , 'r')

plt.xlabel('Time')

plt.ylabel('Stock Prices')

plt.title('Check the accuracy of the model with time')

plt.grid(True)

plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %% [markdown]
# # Prediction Training Data and Check Accuracy

# %%
train_pred = model.predict(trainX)
train_pred = scaler.inverse_transform(train_pred)
trainY = trainY.reshape(trainY.shape[0] , 1)
trainY = scaler.inverse_transform(trainY)
print ('Display Accuracy Training Data')
display (r2_score(trainY,train_pred))
# Out:
# 44/44 [==============================] - 0s 6ms/step
# Display Accuracy Training Data
# 0.8968893957324983

# %% [markdown]
# # Plot The Graph

# %%
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(trainY  , 'b')
plt.plot(train_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %% [markdown]
# Prediction Full Data

# %%
stocks_pred = model.predict(stocksX)
stocks_pred = scaler.inverse_transform(stocks_pred)
stocksY = stocksY.reshape(stocksY.shape[0] , 1)
stocksY = scaler.inverse_transform(stocksY)
print ('Display Accuracy Training Data')
display (r2_score(stocksY,stocks_pred))
# Out:
# 55/55 [==============================] - 0s 6ms/step
# Display Accuracy Training Data
# 0.9089378240030974

# %% [markdown]
# Plot the Graph

# %%
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(stocksY  , 'b')
plt.plot(stocks_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()

# %% [markdown]
# Concat original and prediction data

# %%
results= df[df.symbol.isin (['YHOO'])]
results= results [2:]
df_stocks_pred= pd.DataFrame(stocks_pred, columns = ['Close_Prediction'])
results= pd.concat([results,df_stocks_pred],axis =1)
results.to_excel('results.xlsx')
display(results)
# Out:
#               date symbol       open      close        low       high  \
# 0              NaN    NaN        NaN        NaN        NaN        NaN
# 1              NaN    NaN        NaN        NaN        NaN        NaN
# 2              NaN    NaN        NaN        NaN        NaN        NaN
# 3              NaN    NaN        NaN        NaN        NaN        NaN
# 4              NaN    NaN        NaN        NaN        NaN        NaN
# ...            ...    ...        ...        ...        ...        ...
# 849257  2016-12-23   YHOO  38.459999  38.660000  38.369999  38.810001
# 849757  2016-12-27   YHOO  38.590000  38.919998  38.500000  39.070000
# 850257  2016-12-28   YHOO  39.119999  38.730000  38.709999  39.220001
# 850757  2016-12-29   YHOO  38.759998  38.639999  38.480000  38.930000
# 851257  2016-12-30   YHOO  38.720001  38.669998  38.430000  39.000000
#
#            volume  Close_Prediction
# 0             NaN         21.036781
# 1             NaN         21.064466
# 2             NaN         20.890516
# 3             NaN         20.720371
# 4             NaN         20.733305
# ...           ...               ...
# 849257  3840100.0               NaN
# 849757  4240300.0               NaN
# 850257  4393500.0               NaN
# 850757  4170200.0               NaN
# 851257  6431600.0               NaN
#
# [3519 rows x 8 columns]
